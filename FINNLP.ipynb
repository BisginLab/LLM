# %%
#clone the FinNLP repository
# !git clone https://github.com/hbisgin/FinNLP.git
# Out:
# Cloning into 'FinNLP'...
# remote: Enumerating objects: 1302, done.
# remote: Counting objects: 100% (406/406), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 1302 (delta 239), reused 376 (delta 218), pack-reused 896
# Receiving objects: 100% (1302/1302), 4.32 MiB | 12.08 MiB/s, done.
# Resolving deltas: 100% (590/590), done.

# %%
import sys
sys.path.append('/content/FinNLP/')

# %%
# !pip install parsel
# Out:
# Collecting parsel
#   Downloading parsel-1.8.1-py2.py3-none-any.whl (17 kB)
# Collecting cssselect>=0.9 (from parsel)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting jmespath (from parsel)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from parsel) (4.9.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from parsel) (23.2)
# Collecting w3lib>=1.19.0 (from parsel)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Installing collected packages: w3lib, jmespath, cssselect, parsel
# Successfully installed cssselect-1.2.0 jmespath-1.0.1 parsel-1.8.1 w3lib-2.1.2

# %%
# !pip install finnhub-python
# Out:
# Collecting finnhub-python
#   Downloading finnhub_python-2.4.19-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from finnhub-python) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->finnhub-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->finnhub-python) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->finnhub-python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->finnhub-python) (2024.2.2)
# Installing collected packages: finnhub-python
# Successfully installed finnhub-python-2.4.19

# %%
# Finnhub (Yahoo Finance, Reuters, SeekingAlpha, CNBC...)
from finnlp.data_sources.news.finnhub_date_range import Finnhub_Date_Range

start_date = "2024-01-01"
end_date = "2024-01-03"
config = {
    "use_proxy": "us_free",    # use proxies to prvent ip blocking
    "max_retry": 5,
    "proxy_pages": 5,
    "token": "cmg3oe1r01qv3c72muh0cmg3oe1r01qv3c72muhg"  # Available at https://finnhub.io/dashboard
    #please replace my token with yours.
}

news_downloader = Finnhub_Date_Range(config)                      # init
news_downloader.download_date_range_stock(start_date,end_date)    # Download headers
news_downloader.gather_content()                                  # Download contents
df = news_downloader.dataframe
selected_columns = ["headline", "content"]
df[selected_columns].head(10)
# Out:
# Checking ips: 100%|██████████| 75/75 [00:20<00:00,  3.61it/s]
# Get proxy ips: 75.
# Usable proxy ips: 75.
# Downloading Titles: 100%|██████████| 1/1 [00:01<00:00,  1.30s/it]
# Gathering news contents: 100%|██████████| 185/185 [04:06<00:00,  1.33s/it]
#   headline                                            content
# 0           Apple (AAPL) closed at $184.25 in the latest t...
# 1           By Jonathan Stempel\n(Reuters) - Apple has agr...
# 2                                            Connection Error
# 3           (Refiles to fix day to Wednesday in second par...
# 4           Apple shares extend losses following a downgra...
# 5           It’s January, and that means the entire tech w...
# 6           Investing.com -- U.S. stocks traded in a mixed...
# 7           Hello, tech editor Alexei Oreskovic here. The ...
# 8           Alphabet\n’s GOOGL Google is making advancemen...
# 9           Yesterday was not quite the way Apple (\nNASDA...

# %%
df.to_csv("/content/drive/MyDrive/AAPL_news.csv")
